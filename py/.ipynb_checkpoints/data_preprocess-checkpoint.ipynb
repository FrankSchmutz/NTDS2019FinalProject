# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "flight_data/"

nodes_col_Names = ['Airport_ID', 'Name', 'City', 'Country', 'IATA', 'ICAO', 'Latitude', 'Longitude', 'Altitude', 'Timezone', 'DST', 'Tz_database_time_zone', 'Type', 'Source']
edges_col_Names = ['Airline', 'Airline_ID', 'Source_Airport', 'Source_Airport_ID', 'Destination_Airport', 'Destination_Airport_ID', 'Codeshare', 'Stops', 'Equipment']

nodes_df = pd.read_csv(path+'/airports.dat', names = nodes_col_Names)
edges_df = pd.read_csv(path+'/routes.dat', names = edges_col_Names)

nodes_df.shape
# Out:
# (7184, 14)

# %%
c_1 = pd.read_csv('data/Countries-Continents.csv')
c_1.loc[len(c_1)]=['Asia','Russia'] 
c_1.loc[len(c_1)]=['North America','United States'] 
c_1.loc[len(c_1)]=['Africa','Cote d\'Ivoire'] 
c_1.loc[len(c_1)]=['Africa','Congo (Kinshasa)'] 
c_1.loc[len(c_1)]=['Asia','South Korea'] 
c_1.loc[len(c_1)]=['Asia','Burma'] 
c_1.loc[len(c_1)]=['Europe','Czech Republic'] 
c_1.loc[len(c_1)]=['Asia','North Korea'] 
c_1.loc[len(c_1)]=['Antarctica','Antarctica'] 
c_1.loc[len(c_1)]=['Antarctica','Antarctica'] 
c_1.loc[len(c_1)]=['Asia','Taiwan'] 
c_1.loc[len(c_1)]=['Africa','Congo (Brazzaville)'] 
c_1.loc[len(c_1)]=['Africa','Reunion'] 
c_1.loc[len(c_1)]=['Asia','West Bank'] 
c_1.loc[len(c_1)]=['Asia','Taiwan'] 
c_1.loc[len(c_1)]=['North America','Greenland'] 
c_1.loc[len(c_1)]=['Africa','Burkina Faso'] 
c_1.loc[len(c_1)]=['Europe','Guernsey'] 
c_1.loc[len(c_1)]=['Europe','Jersey']
c_1.loc[len(c_1)]=['Europe','Isle of Man']
c_1.loc[len(c_1)]=['Europe','Isle Of Man']
c_1.loc[len(c_1)]=['South America','Falkland Islands'] 
c_1.loc[len(c_1)]=['Africa','Dzaoudzi'] 
c_1.loc[len(c_1)]=['North America','Saint Pierre and Miquelon'] 
c_1.loc[len(c_1)]=['Europe','Gibraltar']
c_1.loc[len(c_1)]=['South America','British Virgin Islands']
c_1.loc[len(c_1)]=['Oceania','Faroe Islands']
c_1.loc[len(c_1)]=['Oceania','French Polynesia']
c_1.loc[len(c_1)]=['South America','Puerto Rico']
c_1.loc[len(c_1)]=['South America','Guadeloupe']
c_1.loc[len(c_1)]=['Oceania','New Caledonia']
c_1.loc[len(c_1)]=['Oceania','Cocos (Keeling) Islands']
c_1.loc[len(c_1)]=['South America','Turks and Caicos Islands']
c_1.loc[len(c_1)]=['Oceania','Cook Islands']
c_1.loc[len(c_1)]=['Europe','Svalbard']
c_1.loc[len(c_1)]=['South America','American Samoa']
c_1.loc[len(c_1)]=['South America','French Guiana']
c_1.loc[len(c_1)]=['Asia','Guam']
c_1.loc[len(c_1)]=['Asia','Northern Mariana Islands']
c_1.loc[len(c_1)]=['South America','Virgin Islands']
c_1.loc[len(c_1)]=['Europe','Netherlands Antilles']
c_1.loc[len(c_1)]=['Asia','Hong Kong']
c_1.loc[len(c_1)]=['Oceania','Christmas Island']
c_1.loc[len(c_1)]=['North America','Bermuda']
c_1.loc[len(c_1)]=['Africa','Western Sahara']
c_1.loc[len(c_1)]=['North America','Cayman Islands']


nodes_df = nodes_df.merge(c_1, on='Country', how="left")
nodes_df.sort_values(by="Altitude", ascending=False)
nodes_df.shape
# Out:
# (7215, 15)

# %%
# show airports without continent
nodes_df[nodes_df['Continent'].isnull()]
# Out:
#       Airport_ID                                           Name  \
# 872          892                           RAF Ascension Island
# 875          895            Diego Garcia Naval Support Facility
# 895          915        Dzaoudzi Pamandzi International Airport
# 1900        1968                                 Hihifo Airport
# 2159        2253                                Henderson Field
# 2754        2878  Martinique Aimé Césaire International Airport
# 2769        2895            Queen Beatrix International Airport
# 2774        2900                              Wallblake Airport
# 2970        3121                    Macau International Airport
# 3175        3359           Norfolk Island International Airport
# 3763        3969            Yasser Arafat International Airport
# 3918        4146                        John A. Osborne Airport
# 4106        4382                         Johnston Atoll Airport
# 4548        5884                     Niue International Airport
# 4549        5885                            Pointe Vele Airport
# 5164        6787                                  Kalay Airport
# 5717        7674                           Wake Island Airfield
#
#                      City                         Country IATA  ICAO  \
# 872            Wide Awake                    Saint Helena  ASI  FHAW
# 875   Diego Garcia Island  British Indian Ocean Territory   \N  FJDG
# 895              Dzaoudzi                         Mayotte  DZA  FMCZ
# 1900               Wallis               Wallis and Futuna  WLS  NLWW
# 2159               Midway                  Midway Islands  MDY  PMDY
# 2754       Fort-de-france                      Martinique  FDF  TFFF
# 2769           Oranjestad                           Aruba  AUA  TNCA
# 2774           The Valley                        Anguilla  AXA  TQPF
# 2970                Macau                           Macau  MFM  VMMC
# 3175       Norfolk Island                  Norfolk Island  NLK  YSNF
# 3763                 Gaza                       Palestine  GZA  LVGZ
# 3918              Geralds                      Montserrat  MNI  TRPG
# 4106      Johnston Island                  Johnston Atoll  JON  PJON
# 4548                Alofi                            Niue  IUE  NIUE
# 4549        Futuna Island               Wallis and Futuna  FUT  NLWF
# 5164              Kalemyo                         Myanmar  KMV  VYKL
# 5717          Wake island                     Wake Island  AWK  PWAK
#
#        Latitude   Longitude  Altitude Timezone DST Tz_database_time_zone  \
# 872   -7.969600  -14.393700       278        0   N    Atlantic/St_Helena
# 875   -7.313270   72.411102         9        6   U         Indian/Chagos
# 895  -12.804700   45.281101        23        3   U        Indian/Mayotte
# 1900 -13.238300 -176.199005        79       12   U        Pacific/Wallis
# 2159  28.201700 -177.380997        13      -11   U        Pacific/Midway
# 2754  14.591000  -61.003201        16       -4   U    America/Martinique
# 2769  12.501400  -70.015198        60       -4   U         America/Aruba
# 2774  18.204800  -63.055099       127       -4   U      America/Anguilla
# 2970  22.149599  113.592003        20        8   U            Asia/Macau
# 3175 -29.041599  167.938995       371       11   U       Pacific/Norfolk
# 3763  31.246401   34.276100       320        2   U             Asia/Gaza
# 3918  16.791401  -62.193298       550       -4   N    America/Montserrat
# 4106  16.728600 -169.533997         7      -10   U      Pacific/Johnston
# 4548 -19.079031 -169.925598       209      -11   U          Pacific/Niue
# 4549 -14.311400 -178.065994        20       12   U        Pacific/Wallis
# 5164  23.188801   94.051102       499      6.5   U          Asia/Rangoon
# 5717  19.282101  166.636002        14      -10   U      Pacific/Johnston
#
#          Type       Source Continent
# 872   airport  OurAirports       NaN
# 875   airport  OurAirports       NaN
# 895   airport  OurAirports       NaN
# 1900  airport  OurAirports       NaN
# 2159  airport  OurAirports       NaN
# 2754  airport  OurAirports       NaN
# 2769  airport  OurAirports       NaN
# 2774  airport  OurAirports       NaN
# 2970  airport  OurAirports       NaN
# 3175  airport  OurAirports       NaN
# 3763  airport  OurAirports       NaN
# 3918  airport  OurAirports       NaN
# 4106  airport  OurAirports       NaN
# 4548  airport  OurAirports       NaN
# 4549  airport  OurAirports       NaN
# 5164  airport  OurAirports       NaN
# 5717  airport  OurAirports       NaN

# %%
nodes_df["Continent"].value_counts()
# Out:
# North America    2151
# Asia             1618
# Europe           1471
# Africa            707
# South America     690
# Oceania           547
# Antarctica         14
# Name: Continent, dtype: int64

# %%
# search for continent
#nodes_df[nodes_df["Continent"] == "Antarctica"]

# %%
nodes_df["Continent"].unique()
# Out:
# array(['Oceania', 'North America', 'Europe', 'Africa', 'South America',
#        nan, 'Asia', 'Antarctica'], dtype=object)

# %%
nodes_df_export = nodes_df[['Latitude','Longitude','Country','Continent','Airport_ID','IATA']]
nodes_df_export = nodes_df_export.set_index('Airport_ID')
nodes_df_export.columns = [ 'lat', 'lon', 'country', 'continent', 'IATA']
nodes_df_export.to_csv('../data/airports.csv')
nodes_df_export.head()
# Out:
#                  lat         lon           country continent IATA
# Airport_ID
# 1          -6.081690  145.391998  Papua New Guinea   Oceania  GKA
# 2          -5.207080  145.789001  Papua New Guinea   Oceania  MAG
# 3          -5.826790  144.296005  Papua New Guinea   Oceania  HGU
# 4          -6.569803  146.725977  Papua New Guinea   Oceania  LAE
# 5          -9.443380  147.220001  Papua New Guinea   Oceania  POM

# %%
_dict = nodes_df_export.to_dict(orient='records')
_dict[1]
# Out:
# {'lat': -5.20707988739,
#  'lon': 145.789001465,
#  'country': 'Papua New Guinea',
#  'continent': 'Oceania',
#  'IATA': 'MAG'}

# %%
load = pd.read_csv('./web_data/airports.csv')
load
# Out:
#       Airport_ID        lat         lon           country      continent IATA
# 0              1  -6.081690  145.391998  Papua New Guinea        Oceania  GKA
# 1              2  -5.207080  145.789001  Papua New Guinea        Oceania  MAG
# 2              3  -5.826790  144.296005  Papua New Guinea        Oceania  HGU
# 3              4  -6.569803  146.725977  Papua New Guinea        Oceania  LAE
# 4              5  -9.443380  147.220001  Papua New Guinea        Oceania  POM
# 5              6  -3.583830  143.669006  Papua New Guinea        Oceania  WWK
# 6              7  61.160500  -45.425999         Greenland  North America  UAK
# 7              8  64.190903  -51.678101         Greenland  North America  GOH
# 8              9  67.012222  -50.711603         Greenland  North America  SFJ
# 9             10  76.531197  -68.703201         Greenland  North America  THU
# 10            11  65.660004  -18.072701           Iceland         Europe  AEY
